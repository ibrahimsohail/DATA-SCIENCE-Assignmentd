# %%
import pandas as pd
data = pd.read_csv("netflix_data.csv")
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
d = len(data.loc[0,"cast"].split(", "))

d2 = len(data.loc[1,"cast"].split(", "))

d3 = len(data.loc[2,"cast"].split(", "))

d4 = len(data.loc[3,"cast"].split(", "))

d5 = len(data.loc[4,"cast"].split(", "))

# %%
df1 = pd.read_csv("netflix_titles.csv")
df =df1.head(5)

df.insert(4, "num_of_columns", [d, d2, d3, d4, d5], True)
df
# Out:
#   show_id     type                  title         director  num_of_columns  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson              11
# 1      s2  TV Show          Blood & Water              NaN               6
# 2      s3  TV Show              Ganglands  Julien Leclercq               9
# 3      s4  TV Show  Jailbirds New Orleans              NaN               9
# 4      s5  TV Show           Kota Factory              NaN              12
#
#                                                 cast        country  \
# 0                                               None  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                               None            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# ...

# %%
data["genre"]= data["genre"].str.repeat(2)
dups_color = data.pivot_table(columns=['type'], aggfunc='size')
print(dups_color)
# Out:
# type
# Movie      5377
# TV Show    2410
# dtype: int64
